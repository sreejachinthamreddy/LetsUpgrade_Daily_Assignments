# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejachinthamreddy/LetsUpgrade_Daily_Assignments/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autoscraper

# %%
from autoscraper import AutoScraper

# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
pip install autoscraper

# %%
from autoscraper import AutoScraper

# %%
url="https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mobiles%7CMobiles&requestId=c34cba32-cd58-4662-bc4f-06be47829e23&as-searchtext=mobiles"
scraper=AutoScraper()
rest=scraper.build(url,wanted)

# %%
rest
# Out:
# []

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
page=response.content
page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8a1772.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
page_contents=response.text

# %%
page==page_contents
# Out:
# False

# %%
page_contents
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8a1772.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="appl
# ...

# %%
soup=BeautifulSoup(page_contents,'html.parser')

# %%
tags=soup.prettify()
tags

# %%
soup.title.text
# Out:
# 'Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com'

# %%
taaa=soup.find_all('div',class_='_4rR01T')
taaa
# Out:
# [<div class="_4rR01T">realme C11 2021 (Cool Blue, 32 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Grey, 32 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme C21Y (Cross Black, 64 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Blue, 64 GB)</div>,
#  <div class="_4rR01T">realme C11 2021 (Cool Grey, 64 GB)</div>,
#  <div class="_4rR01T">realme 8i (Space Purple, 64 GB)</div>,
#  <div class="_4rR01T">realme 8i (Space Black, 64 GB)</div>,
#  <div class="_4rR01T">POCO M3 (Cool Blue, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone SE (White, 64 GB)</div>,
#  <div class="_4rR01T">Infinix Hot 10 Play (7° Purple, 32 GB)</div>,
#  <div class="_4rR01T">POCO C3 (Matte Black, 32 GB)</div>,
#  <div class="_4rR01T">POCO M3 (Cool Blue, 64 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone SE (Black, 64 GB)</div>,
#  <div class="_4rR01T">Infinix Hot 10 Play (Aegean Blue, 32 GB)</div>,
# ...

# %%
q=[]
for i in taaa:
  q.append(i.text)
len(q)
# Out:
# 24

# %%
price=soup.find_all('div',class_="_30jeq3 _1_WHN1")
w=[]
for i in price:
  w.append(i.text)
len(w)
# Out:
# 24

# %%
import autoscraper
from autoscraper import AutoScraper

# %%
# Out:
# []

# %%
rt=soup.find_all('div',{'class':"_3LWZlK"})
z=[]
rt
len(rt)
# Out:
# 39

# %%
for i in range(len(w)):
 
    z.append(rt[i].text)
len(z)
# Out:
# 24

# %%
import autoscraper
from autoscraper import AutoScraper
wanted=["https://rukminim1.flixcart.com/image/312/312/ksnjp8w0/mobile/k/o/m/c21y-rmx3261-realme-original-imag65kcytrk8dtr.jpeg?q=70"]
scraper=AutoScraper()
restoo=scraper.build(url,wanted)
len(restoo)
x=[]
for i in restoo:
  x.append(i)

# %%
faa=soup.find_all('img',class_='_396cs4 _3exPp9')
u=[]
for i in faa:
  u.append(i['src'])
u
len(u)
# Out:
# 24

# %%
import pandas as pd

# %%
dict={'product name':q,'price':w,'links':u,'rating':z}

# %%
dtframe=pd.DataFrame(dict)

# %%
dtframe
# Out:
#                                   product name  ... rating
# 0           realme C11 2021 (Cool Blue, 32 GB)  ...    4.3
# 1           realme C11 2021 (Cool Grey, 32 GB)  ...    4.3
# 2              realme C21Y (Cross Blue, 64 GB)  ...    4.4
# 3             realme C21Y (Cross Black, 64 GB)  ...    4.4
# 4           realme C11 2021 (Cool Blue, 64 GB)  ...    4.2
# 5           realme C11 2021 (Cool Grey, 64 GB)  ...    4.2
# 6              realme 8i (Space Purple, 64 GB)  ...    4.6
# 7               realme 8i (Space Black, 64 GB)  ...    4.6
# 8                   POCO M3 (Cool Blue, 64 GB)  ...    4.3
# 9               APPLE iPhone SE (White, 64 GB)  ...    4.5
# 10      Infinix Hot 10 Play (7° Purple, 32 GB)  ...    4.3
# 11                POCO C3 (Matte Black, 32 GB)  ...    4.3
# 12                  POCO M3 (Cool Blue, 64 GB)  ...    4.3
# 13              APPLE iPhone SE (Black, 64 GB)  ...    4.5
# 14    Infinix Hot 10 Play (Aegean Blue, 32 GB)  ...    4.3
# ...
